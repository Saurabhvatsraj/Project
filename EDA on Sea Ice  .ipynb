# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\saura\FreeLancer\seaice.csv')
df
# Out:
#        Year   Month   Day       Extent      Missing  \
# 0      1978      10    26       10.231          0.0
# 1      1978      10    28       10.420          0.0
# 2      1978      10    30       10.557          0.0
# 3      1978      11     1       10.670          0.0
# 4      1978      11     3       10.777          0.0
# ...     ...     ...   ...          ...          ...
# 26349  2019       5    27       10.085          0.0
# 26350  2019       5    28       10.078          0.0
# 26351  2019       5    29       10.219          0.0
# 26352  2019       5    30       10.363          0.0
# 26353  2019       5    31       10.436          0.0
#
#                                              Source Data hemisphere
# 0       ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...      north
# 1       ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...      north
# 2       ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...      north
# ...

# %%
df.shape
# Out:
# (26354, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26354 entries, 0 to 26353
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          26354 non-null  int64
#  1    Month        26354 non-null  int64
#  2    Day          26354 non-null  int64
#  3        Extent   26354 non-null  float64
#  4       Missing   26354 non-null  float64
#  5    Source Data  26354 non-null  object
#  6   hemisphere    26354 non-null  object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# Year            0
#  Month          0
#  Day            0
#      Extent     0
#     Missing     0
#  Source Data    0
# hemisphere      0
# dtype: int64

# %%
df.describe()
# Out:
#                Year         Month           Day        Extent       Missing
# count  26354.000000  26354.000000  26354.000000  26354.000000  26354.000000
# mean    2000.591941      6.507399     15.740685     11.494986      0.000003
# std       10.896821      3.451938      8.801607      4.611734      0.000227
# min     1978.000000      1.000000      1.000000      2.080000      0.000000
# 25%     1992.000000      4.000000      8.000000      7.601000      0.000000
# 50%     2001.000000      7.000000     16.000000     12.217000      0.000000
# 75%     2010.000000     10.000000     23.000000     15.114000      0.000000
# max     2019.000000     12.000000     31.000000     20.201000      0.024000

# %%
#Show heatmap  using seaborn lib.
plt.figure(figsize=(12,8))
x=sns.heatmap(df.corr(),annot=True)
x
# Out:
# <AxesSubplot:>

# %%
x.figure.savefig("HeatMap on Ice data.png")

# %% [markdown]
#  there are no missing values
#
# the dataset has 26354 rows
#
# the dataset begins in October 1978 and ends in May 2019
#
# the columns of interest are year, month, day and extent
#
# The month variable is the most correlated with the sea ice extent (SIE)

# %%
#ice extent on the year bases
plt.figure(figsize=(12,8))
plt.title("ICE EXTENT ON THE YEAR BASIS")
plt.xlabel('Years Present')
plt.ylabel('Sea Ice Extent, 10^6 sq km')

x=plt.scatter(df['Year'],df['     Extent'])
x

# %%
x.figure.savefig("ICE EXTENT ON THE YEAR BASIS.png")

# %%
#ice missing  on the year bases
#plt.figure(figsize=(12,8))
plt.title("ICE MISSING ON THE YEAR BASIS")
plt.xlabel('Years Present')
plt.ylabel('Sea Ice Missing, 10^6 sq km')

x=plt.scatter(df['Year'],df['    Missing'])
x

# %%
x.figure.savefig("ICE MISSING ON THE YEAR BASIS.png")

# %%
#ice extent on the Months bases
plt.figure(figsize=(12,8))
plt.title("ICE EXTENT ON THE Months BASIS")
plt.xlabel('Month  Present')
plt.ylabel('Sea Ice Extent, 10^6 sq km')

x=plt.scatter(df[' Month'],df['     Extent'])

# %%
x.figure.savefig("ICE EXTENT ON THE Months BASIS.png")

# %%
#ice missing  on the Month bases
plt.figure(figsize=(12,8))
plt.title("ICE MISSING ON THE Months BASIS")
plt.xlabel('Month Present')
plt.ylabel('Sea Ice Missing, 10^6 sq km')

x=plt.scatter(df[' Month'],df['    Missing'])
x

# %%
x.figure.savefig("ICE MISSING ON THE Months BASIS.png")

# %%
#ice extent on the day bases
plt.figure(figsize=(12,8))
plt.title("ICE EXTENT ON THE DAY BASIS")
plt.xlabel('Day Present')
plt.ylabel('Sea Ice Extent, 10^6 sq km')

X=plt.scatter(df[ ' Day'],df['     Extent'])
X

# %%
X.figure.savefig("ICE EXTENT ON THE DAY BASIS.png")

# %%
#ice missing  on the day bases
plt.figure(figsize=(12,8))
plt.title("ICE MISSING ON THE DAY BASIS")
plt.xlabel('Day Present')
plt.ylabel('Sea Ice Missing, 10^6 sq km')

X=plt.scatter(df[' Day'],df['    Missing'])
X

# %%
X.figure.savefig("ICE MISSING ON THE DAY BASIS.png")

# %%
#ice extent on the 'hemisphere' bases

plt.title("ICE EXTENT ON THE hemisphere BASIS")
plt.xlabel('hemisphere Present')
plt.ylabel('Sea Ice Extent, 10^6 sq km')

X=plt.scatter(df['hemisphere'],df['     Extent'])
X

# %%
X.figure.savefig("ICE EXTENT ON THE hemisphere BASIS.png")

# %%
#ice missing  on the 'hemisphere' bases

plt.title("ICE MISSING  ON THE hemisphere BASIS")
plt.xlabel('hemisphere Present')
plt.ylabel('Sea Ice Missing, 10^6 sq km')

X=plt.scatter(df['hemisphere'],df[ '    Missing'])
X

# %%
X.figure.savefig("ICE MISSING ON THE hemisphere BASIS.png")
