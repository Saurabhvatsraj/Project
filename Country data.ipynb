# %%
import pandas as pd
f1=pd.read_csv(r'C:\Users\saura\FreeLancer\world-bank-data-analysis-master\world-bank-data-analysis-master\Canada.csv')
f1.head(1)
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0        37058856.0         18674525.0       18384331.0   14.693103
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0    7.237931                       10.0                     19.455
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                         1.502                                0.947
#
#    Female Employment in Industry(%)  Unemployment(%)    GDP in USD  \
# 0                             8.401             5.92  1.713342e+12
#
#    National Income per Capita  Net income from Abroad  \
# 0                    1.699046           -2.215552e+10
#
#    Agriculture value added(in USD)  \
# 0                     2.012919e+10
#
#    Electric Power Consumption(kWH per capita)  \
# 0                                13266.022107
#
#    Renewable Energy Consumption (%)  Fossil Fuel Consumption (%)  Year Country
# ...

# %%
f2=pd.read_csv(r'C:\Users\saura\FreeLancer\world-bank-data-analysis-master\world-bank-data-analysis-master\China.csv')
f2.head(1)
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0      1.392730e+09        677972245.0      714757755.0   20.537241
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0    7.601207                        9.0                  28.620001
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                         26.77                            24.235001
#
#    Female Employment in Industry(%)  Unemployment(%)    GDP in USD  \
# 0                            28.267            4.417  1.360815e+13
#
#    National Income per Capita  Net income from Abroad  \
# 0                    8.678595           -5.129870e+10
#
#    Agriculture value added(in USD)  \
# 0                     9.784525e+11
#
#    Electric Power Consumption(kWH per capita)  \
# 0                                 1081.571912
#
#    Renewable Energy Consumption (%)  Fossil Fuel Consumption (%)  Year Country
# ...

# %%
f3=pd.read_csv(r'C:\Users\saura\FreeLancer\world-bank-data-analysis-master\world-bank-data-analysis-master\Great Britain.csv')
f3.head(1)
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0        66488991.0         33666883.0       32822108.0   13.689655
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0   10.884483                       11.0                     18.107
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                         1.147                                0.635
#
#    Female Employment in Industry(%)  Unemployment(%)    GDP in USD  \
# 0                             7.567            3.954  2.855297e+12
#
#    National Income per Capita  Net income from Abroad  \
# 0                    1.930068           -3.849080e+10
#
#    Agriculture value added(in USD)  \
# 0                     1.802072e+10
#
#    Electric Power Consumption(kWH per capita)  \
# 0                                 4908.429642
#
#    Renewable Energy Consumption (%)  Fossil Fuel Consumption (%)  Year  \
# ...

# %%
f4=pd.read_csv(r'C:\Users\saura\FreeLancer\world-bank-data-analysis-master\world-bank-data-analysis-master\India.csv')
f4.head(1)
# Out:
#    Total Population  Female Population  Birth Rate  Death Rate  \
# 0      1.352617e+09        649574719.0   31.324362   12.256448
#
#    Compulsory Education Dur.  Employment in Industry(%)  \
# 0                        8.0                  24.686001
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                     43.860001                            57.060001
#
#    Female Employment in Industry(%)  Unemployment(%)    GDP in USD  \
# 0                         18.747999            2.551  2.718732e+12
#
#    National Income per Capita  Net income from Abroad  \
# 0                    3.470426           -2.769137e+10
#
#    Agriculture value added(in USD)  \
# 0                     3.969875e+11
#
#    Electric Power Consumption(kWH per capita)  \
# 0                                  335.182371
#
#    Renewable Energy Consumption (%)  Fossil Fuel Consumption (%)  Year  \
# 0                         48.435321                    54.656074  2018
#
# ...

# %%
f5=pd.read_csv(r'C:\Users\saura\FreeLancer\world-bank-data-analysis-master\world-bank-data-analysis-master\Japan.csv')
f5.head(1)
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0       126529100.0         64731350.0       61797750.0   12.381498
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0    7.466062                        9.0                  24.500999
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                         3.409                                2.956
#
#    Female Employment in Industry(%)  Unemployment(%)    GDP in USD  \
# 0                            14.007            2.445  4.971323e+12
#
#    National Income per Capita  Net income from Abroad  \
# 0                    1.812481            5.911426e+10
#
#    Agriculture value added(in USD)  \
# 0                     6.343287e+10
#
#    Electric Power Consumption(kWH per capita)  \
# 0                                 5650.117744
#
#    Renewable Energy Consumption (%)  Fossil Fuel Consumption (%)  Year Country
# ...

# %%
f6=pd.read_csv(r'C:\Users\saura\FreeLancer\world-bank-data-analysis-master\world-bank-data-analysis-master\South Africa.csv')
f6.head(1)
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0        57779622.0         29290888.0       28488734.0   30.794948
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0   11.900172                        9.0                     23.243
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                         5.157                                3.663
#
#    Female Employment in Industry(%)  Unemployment(%)    GDP in USD  \
# 0                            12.135           26.958  3.682889e+11
#
#    National Income per Capita  Net income from Abroad  \
# 0                    1.081945           -1.164018e+10
#
#    Agriculture value added(in USD)  \
# 0                     8.014040e+09
#
#    Electric Power Consumption(kWH per capita)  \
# 0                                 3991.571087
#
#    Renewable Energy Consumption (%)  Fossil Fuel Consumption (%)  Year  \
# ...

# %%
f7=pd.read_csv(r'C:\Users\saura\FreeLancer\world-bank-data-analysis-master\world-bank-data-analysis-master\USA.csv')
f7.head(1)
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0       327167434.0        165285036.0      161882398.0   15.662069
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0    8.744052                       12.0                     19.437
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                         1.423                                0.755
#
#    Female Employment in Industry(%)  Unemployment(%)    GDP in USD  \
# 0                             8.495            3.933  2.054434e+13
#
#    National Income per Capita  Net income from Abroad  \
# 0                    1.735523            2.679000e+11
#
#    Agriculture value added(in USD)  \
# 0                     1.527789e+11
#
#    Electric Power Consumption(kWH per capita)  \
# 0                                10318.049364
#
#    Renewable Energy Consumption (%)  Fossil Fuel Consumption (%)  Year Country
# ...

# %%
df=pd.concat([f1,f2,f3,f4,f5,f6,f7])

# %%
df
# Out:
#     Total Population  Female Population  Male Population  Birth Rate  \
# 0         37058856.0         18674525.0       18384331.0   14.693103
# 1         36540268.0         18417231.0       18123037.0   10.300000
# 2         36109487.0         18202997.0       17906490.0   10.600000
# 3         35702908.0         17999309.0       17703599.0   10.700000
# 4         35437435.0         17864828.0       17572607.0   10.800000
# ..               ...                ...              ...         ...
# 54       191889000.0         96951949.0       94937051.0   21.100000
# 55       189242000.0         95575715.0       93666285.0   21.700000
# 56       186538000.0         94180305.0       92357695.0   22.400000
# 57       183691000.0         92714569.0       90976431.0   23.300000
# 58       180671000.0         91157654.0       89513346.0   23.700000
#
#     Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# ...

# %%
df.shape
# Out:
# (413, 20)

# %%
dff=pd.DataFrame(df)
dff.to_csv("country.csv")
df1=pd.read_csv("country.csv")

# %%
df1
# Out:
#      Unnamed: 0  Total Population  Female Population  Male Population  \
# 0             0        37058856.0         18674525.0       18384331.0
# 1             1        36540268.0         18417231.0       18123037.0
# 2             2        36109487.0         18202997.0       17906490.0
# 3             3        35702908.0         17999309.0       17703599.0
# 4             4        35437435.0         17864828.0       17572607.0
# ..          ...               ...                ...              ...
# 408          54       191889000.0         96951949.0       94937051.0
# 409          55       189242000.0         95575715.0       93666285.0
# 410          56       186538000.0         94180305.0       92357695.0
# 411          57       183691000.0         92714569.0       90976431.0
# 412          58       180671000.0         91157654.0       89513346.0
#
#      Birth Rate  Death Rate  Compulsory Education Dur.  \
# 0     14.693103    7.237931                       10.0
# ...
